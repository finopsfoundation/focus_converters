# %%
# List available providers

# !python -m focus_converter.main list-providers
# Out:
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# {
#     "providers": [
#         "azure",
#         "gcp",
#         "aws",
#         "oci"
#     ]
# }

# %%
from focus_converter.converter import FocusConverter

from IPython import display

# %%
# Show GCP conversion plan

converter = FocusConverter()
converter.load_provider_conversion_configs()
converter.prepare_horizontal_conversion_plan(provider="gcp")
display.Image(converter.explain())

# %%
# Show AWS conversion plan

converter = FocusConverter()
converter.load_provider_conversion_configs()
converter.prepare_horizontal_conversion_plan(provider="aws")
display.Image(converter.explain())

# %%
# Show Azure conversion plan

converter = FocusConverter()
converter.load_provider_conversion_configs()
converter.prepare_horizontal_conversion_plan(provider="azure")
display.Image(converter.explain())
